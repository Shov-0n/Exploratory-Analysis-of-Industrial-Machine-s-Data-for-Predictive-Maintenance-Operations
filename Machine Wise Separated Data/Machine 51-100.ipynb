# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("features.csv")

# %% [markdown]
# # Start

# %%
#machine51




machine_ID_51 = df.loc[df['machineID'] == 51]
machine_ID_51.to_csv('machine_ID_51.csv')


machine_ID_51 = pd.read_csv("machine_ID_51.csv")

del machine_ID_51["Unnamed: 0"]


machine_ID_51["time_diff"] = np.nan

machine_ID_51.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_51.index:
    
    machine_ID_51.at[(idx+1), 'time_diff'] = machine_ID_51.at[(idx), 'time_diff'] + 3.0 

machine_ID_51 = machine_ID_51.drop([2913])    


machine_ID_51.to_csv('machine_ID_51.csv') # save file

# %%
#machine52




machine_ID_52 = df.loc[df['machineID'] == 52]
machine_ID_52.to_csv('machine_ID_52.csv')


machine_ID_52 = pd.read_csv("machine_ID_52.csv")

del machine_ID_52["Unnamed: 0"]


machine_ID_52["time_diff"] = np.nan

machine_ID_52.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_52.index:
    
    machine_ID_52.at[(idx+1), 'time_diff'] = machine_ID_52.at[(idx), 'time_diff'] + 3.0 

machine_ID_52 = machine_ID_52.drop([2913])    


machine_ID_52.to_csv('machine_ID_52.csv') # save file

# %%
#machine53




machine_ID_53 = df.loc[df['machineID'] == 53]
machine_ID_53.to_csv('machine_ID_53.csv')


machine_ID_53 = pd.read_csv("machine_ID_53.csv")

del machine_ID_53["Unnamed: 0"]


machine_ID_53["time_diff"] = np.nan

machine_ID_53.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_53.index:
    
    machine_ID_53.at[(idx+1), 'time_diff'] = machine_ID_53.at[(idx), 'time_diff'] + 3.0 

machine_ID_53 = machine_ID_53.drop([2913])    


machine_ID_53.to_csv('machine_ID_53.csv') # save file

# %%
#machine54




machine_ID_54 = df.loc[df['machineID'] == 54]
machine_ID_54.to_csv('machine_ID_54.csv')


machine_ID_54 = pd.read_csv("machine_ID_54.csv")

del machine_ID_54["Unnamed: 0"]


machine_ID_54["time_diff"] = np.nan

machine_ID_54.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_54.index:
    
    machine_ID_54.at[(idx+1), 'time_diff'] = machine_ID_54.at[(idx), 'time_diff'] + 3.0 

machine_ID_54 = machine_ID_54.drop([2913])    


machine_ID_54.to_csv('machine_ID_54.csv') # save file

# %%
#machine55




machine_ID_55 = df.loc[df['machineID'] == 55]
machine_ID_55.to_csv('machine_ID_55.csv')


machine_ID_55 = pd.read_csv("machine_ID_55.csv")

del machine_ID_55["Unnamed: 0"]


machine_ID_55["time_diff"] = np.nan

machine_ID_55.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_55.index:
    
    machine_ID_55.at[(idx+1), 'time_diff'] = machine_ID_55.at[(idx), 'time_diff'] + 3.0 

machine_ID_55 = machine_ID_55.drop([2913])    


machine_ID_55.to_csv('machine_ID_55.csv') # save file

# %%
#machine56




machine_ID_56 = df.loc[df['machineID'] == 56]
machine_ID_56.to_csv('machine_ID_56.csv')


machine_ID_56 = pd.read_csv("machine_ID_56.csv")

del machine_ID_56["Unnamed: 0"]


machine_ID_56["time_diff"] = np.nan

machine_ID_56.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_56.index:
    
    machine_ID_56.at[(idx+1), 'time_diff'] = machine_ID_56.at[(idx), 'time_diff'] + 3.0 

machine_ID_56 = machine_ID_56.drop([2913])    


machine_ID_56.to_csv('machine_ID_56.csv') # save file

# %%
#machine57




machine_ID_57 = df.loc[df['machineID'] == 57]
machine_ID_57.to_csv('machine_ID_57.csv')


machine_ID_57 = pd.read_csv("machine_ID_57.csv")

del machine_ID_57["Unnamed: 0"]


machine_ID_57["time_diff"] = np.nan

machine_ID_57.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_57.index:
    
    machine_ID_57.at[(idx+1), 'time_diff'] = machine_ID_57.at[(idx), 'time_diff'] + 3.0 

machine_ID_57 = machine_ID_57.drop([2913])    


machine_ID_57.to_csv('machine_ID_57.csv') # save file

# %%
#machine58




machine_ID_58 = df.loc[df['machineID'] == 58]
machine_ID_58.to_csv('machine_ID_58.csv')


machine_ID_58 = pd.read_csv("machine_ID_58.csv")

del machine_ID_58["Unnamed: 0"]


machine_ID_58["time_diff"] = np.nan

machine_ID_58.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_58.index:
    
    machine_ID_58.at[(idx+1), 'time_diff'] = machine_ID_58.at[(idx), 'time_diff'] + 3.0 

machine_ID_58 = machine_ID_58.drop([2913])    


machine_ID_58.to_csv('machine_ID_58.csv') # save file

# %%
#machine59




machine_ID_59 = df.loc[df['machineID'] == 59]
machine_ID_59.to_csv('machine_ID_59.csv')


machine_ID_59 = pd.read_csv("machine_ID_59.csv")

del machine_ID_59["Unnamed: 0"]


machine_ID_59["time_diff"] = np.nan

machine_ID_59.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_59.index:
    
    machine_ID_59.at[(idx+1), 'time_diff'] = machine_ID_59.at[(idx), 'time_diff'] + 3.0 

machine_ID_59 = machine_ID_59.drop([2913])    


machine_ID_59.to_csv('machine_ID_59.csv') # save file

# %%
#machine60




machine_ID_60 = df.loc[df['machineID'] == 60]
machine_ID_60.to_csv('machine_ID_60.csv')


machine_ID_60 = pd.read_csv("machine_ID_60.csv")

del machine_ID_60["Unnamed: 0"]


machine_ID_60["time_diff"] = np.nan

machine_ID_60.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_60.index:
    
    machine_ID_60.at[(idx+1), 'time_diff'] = machine_ID_60.at[(idx), 'time_diff'] + 3.0 

machine_ID_60 = machine_ID_60.drop([2913])    


machine_ID_60.to_csv('machine_ID_60.csv') # save file

# %%
#machine61




machine_ID_61 = df.loc[df['machineID'] == 61]
machine_ID_61.to_csv('machine_ID_61.csv')


machine_ID_61 = pd.read_csv("machine_ID_61.csv")

del machine_ID_61["Unnamed: 0"]


machine_ID_61["time_diff"] = np.nan

machine_ID_61.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_61.index:
    
    machine_ID_61.at[(idx+1), 'time_diff'] = machine_ID_61.at[(idx), 'time_diff'] + 3.0 

machine_ID_61 = machine_ID_61.drop([2913])    


machine_ID_61.to_csv('machine_ID_61.csv') # save file

# %%
#machine62




machine_ID_62 = df.loc[df['machineID'] == 62]
machine_ID_62.to_csv('machine_ID_62.csv')


machine_ID_62 = pd.read_csv("machine_ID_62.csv")

del machine_ID_62["Unnamed: 0"]


machine_ID_62["time_diff"] = np.nan

machine_ID_62.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_62.index:
    
    machine_ID_62.at[(idx+1), 'time_diff'] = machine_ID_62.at[(idx), 'time_diff'] + 3.0 

machine_ID_62 = machine_ID_62.drop([2913])    


machine_ID_62.to_csv('machine_ID_62.csv') # save file

# %%
#machine63




machine_ID_63 = df.loc[df['machineID'] == 63]
machine_ID_63.to_csv('machine_ID_63.csv')


machine_ID_63 = pd.read_csv("machine_ID_63.csv")

del machine_ID_63["Unnamed: 0"]


machine_ID_63["time_diff"] = np.nan

machine_ID_63.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_63.index:
    
    machine_ID_63.at[(idx+1), 'time_diff'] = machine_ID_63.at[(idx), 'time_diff'] + 3.0 

machine_ID_63 = machine_ID_63.drop([2913])    


machine_ID_63.to_csv('machine_ID_63.csv') # save file

# %%
#machine64




machine_ID_64 = df.loc[df['machineID'] == 64]
machine_ID_64.to_csv('machine_ID_64.csv')


machine_ID_64 = pd.read_csv("machine_ID_64.csv")

del machine_ID_64["Unnamed: 0"]


machine_ID_64["time_diff"] = np.nan

machine_ID_64.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_64.index:
    
    machine_ID_64.at[(idx+1), 'time_diff'] = machine_ID_64.at[(idx), 'time_diff'] + 3.0 

machine_ID_64 = machine_ID_64.drop([2913])    


machine_ID_64.to_csv('machine_ID_64.csv') # save file

# %%
#machine65




machine_ID_65 = df.loc[df['machineID'] == 65]
machine_ID_65.to_csv('machine_ID_65.csv')


machine_ID_65 = pd.read_csv("machine_ID_65.csv")

del machine_ID_65["Unnamed: 0"]


machine_ID_65["time_diff"] = np.nan

machine_ID_65.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_65.index:
    
    machine_ID_65.at[(idx+1), 'time_diff'] = machine_ID_65.at[(idx), 'time_diff'] + 3.0 

machine_ID_65 = machine_ID_65.drop([2913])    


machine_ID_65.to_csv('machine_ID_65.csv') # save file

# %%
#machine66




machine_ID_66 = df.loc[df['machineID'] == 66]
machine_ID_66.to_csv('machine_ID_66.csv')


machine_ID_66 = pd.read_csv("machine_ID_66.csv")

del machine_ID_66["Unnamed: 0"]


machine_ID_66["time_diff"] = np.nan

machine_ID_66.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_66.index:
    
    machine_ID_66.at[(idx+1), 'time_diff'] = machine_ID_66.at[(idx), 'time_diff'] + 3.0 

machine_ID_66 = machine_ID_66.drop([2913])    


machine_ID_66.to_csv('machine_ID_66.csv') # save file

# %%
#machine67




machine_ID_67 = df.loc[df['machineID'] == 67]
machine_ID_67.to_csv('machine_ID_67.csv')


machine_ID_67 = pd.read_csv("machine_ID_67.csv")

del machine_ID_67["Unnamed: 0"]


machine_ID_67["time_diff"] = np.nan

machine_ID_67.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_67.index:
    
    machine_ID_67.at[(idx+1), 'time_diff'] = machine_ID_67.at[(idx), 'time_diff'] + 3.0 

machine_ID_67 = machine_ID_67.drop([2913])    


machine_ID_67.to_csv('machine_ID_67.csv') # save file

# %%
#machine68




machine_ID_68 = df.loc[df['machineID'] == 68]
machine_ID_68.to_csv('machine_ID_68.csv')


machine_ID_68 = pd.read_csv("machine_ID_68.csv")

del machine_ID_68["Unnamed: 0"]


machine_ID_68["time_diff"] = np.nan

machine_ID_68.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_68.index:
    
    machine_ID_68.at[(idx+1), 'time_diff'] = machine_ID_68.at[(idx), 'time_diff'] + 3.0 

machine_ID_68 = machine_ID_68.drop([2913])    


machine_ID_68.to_csv('machine_ID_68.csv') # save file

# %%
#machine69




machine_ID_69 = df.loc[df['machineID'] == 69]
machine_ID_69.to_csv('machine_ID_69.csv')


machine_ID_69 = pd.read_csv("machine_ID_69.csv")

del machine_ID_69["Unnamed: 0"]


machine_ID_69["time_diff"] = np.nan

machine_ID_69.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_69.index:
    
    machine_ID_69.at[(idx+1), 'time_diff'] = machine_ID_69.at[(idx), 'time_diff'] + 3.0 

machine_ID_69 = machine_ID_69.drop([2913])    


machine_ID_69.to_csv('machine_ID_69.csv') # save file

# %%
#machine70




machine_ID_70 = df.loc[df['machineID'] == 70]
machine_ID_70.to_csv('machine_ID_70.csv')


machine_ID_70 = pd.read_csv("machine_ID_70.csv")

del machine_ID_70["Unnamed: 0"]


machine_ID_70["time_diff"] = np.nan

machine_ID_70.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_70.index:
    
    machine_ID_70.at[(idx+1), 'time_diff'] = machine_ID_70.at[(idx), 'time_diff'] + 3.0 

machine_ID_70 = machine_ID_70.drop([2913])    


machine_ID_70.to_csv('machine_ID_70.csv') # save file

# %%
#machine71




machine_ID_71 = df.loc[df['machineID'] == 71]
machine_ID_71.to_csv('machine_ID_71.csv')


machine_ID_71 = pd.read_csv("machine_ID_71.csv")

del machine_ID_71["Unnamed: 0"]


machine_ID_71["time_diff"] = np.nan

machine_ID_71.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_71.index:
    
    machine_ID_71.at[(idx+1), 'time_diff'] = machine_ID_71.at[(idx), 'time_diff'] + 3.0 

machine_ID_71 = machine_ID_71.drop([2913])    


machine_ID_71.to_csv('machine_ID_71.csv') # save file

# %%
#machine72




machine_ID_72 = df.loc[df['machineID'] == 72]
machine_ID_72.to_csv('machine_ID_72.csv')


machine_ID_72 = pd.read_csv("machine_ID_72.csv")

del machine_ID_72["Unnamed: 0"]


machine_ID_72["time_diff"] = np.nan

machine_ID_72.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_72.index:
    
    machine_ID_72.at[(idx+1), 'time_diff'] = machine_ID_72.at[(idx), 'time_diff'] + 3.0 

machine_ID_72 = machine_ID_72.drop([2913])    


machine_ID_72.to_csv('machine_ID_72.csv') # save file

# %%
#machine73


machine_ID_73 = df.loc[df['machineID'] == 73]
machine_ID_73.to_csv('machine_ID_73.csv')


machine_ID_73 = pd.read_csv("machine_ID_73.csv")

del machine_ID_73["Unnamed: 0"]


machine_ID_73["time_diff"] = np.nan

machine_ID_73.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_73.index:
    
    machine_ID_73.at[(idx+1), 'time_diff'] = machine_ID_73.at[(idx), 'time_diff'] + 3.0 

machine_ID_73 = machine_ID_73.drop([2913])    


machine_ID_73.to_csv('machine_ID_73.csv') # save file

# %%
#machine74




machine_ID_74 = df.loc[df['machineID'] == 74]
machine_ID_74.to_csv('machine_ID_74.csv')


machine_ID_74 = pd.read_csv("machine_ID_74.csv")

del machine_ID_74["Unnamed: 0"]


machine_ID_74["time_diff"] = np.nan

machine_ID_74.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_74.index:
    
    machine_ID_74.at[(idx+1), 'time_diff'] = machine_ID_74.at[(idx), 'time_diff'] + 3.0 

machine_ID_74 = machine_ID_74.drop([2913])    


machine_ID_74.to_csv('machine_ID_74.csv') # save file

# %%
#machine75




machine_ID_75 = df.loc[df['machineID'] == 75]
machine_ID_75.to_csv('machine_ID_75.csv')


machine_ID_75 = pd.read_csv("machine_ID_75.csv")

del machine_ID_75["Unnamed: 0"]


machine_ID_75["time_diff"] = np.nan

machine_ID_75.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_75.index:
    
    machine_ID_75.at[(idx+1), 'time_diff'] = machine_ID_75.at[(idx), 'time_diff'] + 3.0 

machine_ID_75 = machine_ID_75.drop([2913])    


machine_ID_75.to_csv('machine_ID_75.csv') # save file

# %%
#machine76




machine_ID_76 = df.loc[df['machineID'] == 76]
machine_ID_76.to_csv('machine_ID_76.csv')


machine_ID_76 = pd.read_csv("machine_ID_76.csv")

del machine_ID_76["Unnamed: 0"]


machine_ID_76["time_diff"] = np.nan

machine_ID_76.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_76.index:
    
    machine_ID_76.at[(idx+1), 'time_diff'] = machine_ID_76.at[(idx), 'time_diff'] + 3.0 

machine_ID_76 = machine_ID_76.drop([2913])    


machine_ID_76.to_csv('machine_ID_76.csv') # save file

# %%
#machine77




machine_ID_77 = df.loc[df['machineID'] == 77]
machine_ID_77.to_csv('machine_ID_77.csv')


machine_ID_77 = pd.read_csv("machine_ID_77.csv")

del machine_ID_77["Unnamed: 0"]


machine_ID_77["time_diff"] = np.nan

machine_ID_77.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_77.index:
    
    machine_ID_77.at[(idx+1), 'time_diff'] = machine_ID_77.at[(idx), 'time_diff'] + 3.0 

machine_ID_77 = machine_ID_77.drop([2913])    


machine_ID_77.to_csv('machine_ID_77.csv') # save file

# %%
#machine78




machine_ID_78 = df.loc[df['machineID'] == 78]
machine_ID_78.to_csv('machine_ID_78.csv')


machine_ID_78 = pd.read_csv("machine_ID_78.csv")

del machine_ID_78["Unnamed: 0"]


machine_ID_78["time_diff"] = np.nan

machine_ID_78.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_78.index:
    
    machine_ID_78.at[(idx+1), 'time_diff'] = machine_ID_78.at[(idx), 'time_diff'] + 3.0 

machine_ID_78 = machine_ID_78.drop([2913])    


machine_ID_78.to_csv('machine_ID_78.csv') # save file

# %%
#machine79




machine_ID_79 = df.loc[df['machineID'] == 79]
machine_ID_79.to_csv('machine_ID_79.csv')


machine_ID_79 = pd.read_csv("machine_ID_79.csv")

del machine_ID_79["Unnamed: 0"]


machine_ID_79["time_diff"] = np.nan

machine_ID_79.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_79.index:
    
    machine_ID_79.at[(idx+1), 'time_diff'] = machine_ID_79.at[(idx), 'time_diff'] + 3.0 

machine_ID_79 = machine_ID_79.drop([2913])    


machine_ID_79.to_csv('machine_ID_79.csv') # save file

# %%
#machine80




machine_ID_80 = df.loc[df['machineID'] == 80]
machine_ID_80.to_csv('machine_ID_80.csv')


machine_ID_80 = pd.read_csv("machine_ID_80.csv")

del machine_ID_80["Unnamed: 0"]


machine_ID_80["time_diff"] = np.nan

machine_ID_80.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_80.index:
    
    machine_ID_80.at[(idx+1), 'time_diff'] = machine_ID_80.at[(idx), 'time_diff'] + 3.0 

machine_ID_80 = machine_ID_80.drop([2913])    


machine_ID_80.to_csv('machine_ID_80.csv') # save file

# %%
#machine81




machine_ID_81 = df.loc[df['machineID'] == 81]
machine_ID_81.to_csv('machine_ID_81.csv')


machine_ID_81 = pd.read_csv("machine_ID_81.csv")

del machine_ID_81["Unnamed: 0"]


machine_ID_81["time_diff"] = np.nan

machine_ID_81.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_81.index:
    
    machine_ID_81.at[(idx+1), 'time_diff'] = machine_ID_81.at[(idx), 'time_diff'] + 3.0 

machine_ID_81 = machine_ID_81.drop([2913])    


machine_ID_81.to_csv('machine_ID_81.csv') # save file

# %%
#machine82




machine_ID_82 = df.loc[df['machineID'] == 82]
machine_ID_82.to_csv('machine_ID_82.csv')


machine_ID_82 = pd.read_csv("machine_ID_82.csv")

del machine_ID_82["Unnamed: 0"]


machine_ID_82["time_diff"] = np.nan

machine_ID_82.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_82.index:
    
    machine_ID_82.at[(idx+1), 'time_diff'] = machine_ID_82.at[(idx), 'time_diff'] + 3.0 

machine_ID_82 = machine_ID_82.drop([2913])    


machine_ID_82.to_csv('machine_ID_82.csv') # save file

# %%
#machine83




machine_ID_83 = df.loc[df['machineID'] == 83]
machine_ID_83.to_csv('machine_ID_83.csv')


machine_ID_83 = pd.read_csv("machine_ID_83.csv")

del machine_ID_83["Unnamed: 0"]


machine_ID_83["time_diff"] = np.nan

machine_ID_83.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_83.index:
    
    machine_ID_83.at[(idx+1), 'time_diff'] = machine_ID_83.at[(idx), 'time_diff'] + 3.0 

machine_ID_83 = machine_ID_83.drop([2913])    


machine_ID_83.to_csv('machine_ID_83.csv') # save file

# %%
#machine84




machine_ID_84 = df.loc[df['machineID'] == 84]
machine_ID_84.to_csv('machine_ID_84.csv')


machine_ID_84 = pd.read_csv("machine_ID_84.csv")

del machine_ID_84["Unnamed: 0"]


machine_ID_84["time_diff"] = np.nan

machine_ID_84.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_84.index:
    
    machine_ID_84.at[(idx+1), 'time_diff'] = machine_ID_84.at[(idx), 'time_diff'] + 3.0 

machine_ID_84 = machine_ID_84.drop([2913])    


machine_ID_84.to_csv('machine_ID_84.csv') # save file

# %%
#machine85




machine_ID_85 = df.loc[df['machineID'] == 85]
machine_ID_85.to_csv('machine_ID_85.csv')


machine_ID_85 = pd.read_csv("machine_ID_85.csv")

del machine_ID_85["Unnamed: 0"]


machine_ID_85["time_diff"] = np.nan

machine_ID_85.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_85.index:
    
    machine_ID_85.at[(idx+1), 'time_diff'] = machine_ID_85.at[(idx), 'time_diff'] + 3.0 

machine_ID_85 = machine_ID_85.drop([2913])    


machine_ID_85.to_csv('machine_ID_85.csv') # save file

# %%
#machine86




machine_ID_86 = df.loc[df['machineID'] == 86]
machine_ID_86.to_csv('machine_ID_86.csv')


machine_ID_86 = pd.read_csv("machine_ID_86.csv")

del machine_ID_86["Unnamed: 0"]


machine_ID_86["time_diff"] = np.nan

machine_ID_86.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_86.index:
    
    machine_ID_86.at[(idx+1), 'time_diff'] = machine_ID_86.at[(idx), 'time_diff'] + 3.0 

machine_ID_86 = machine_ID_86.drop([2913])    


machine_ID_86.to_csv('machine_ID_86.csv') # save file

# %%
#machine87




machine_ID_87 = df.loc[df['machineID'] == 87]
machine_ID_87.to_csv('machine_ID_87.csv')


machine_ID_87 = pd.read_csv("machine_ID_87.csv")

del machine_ID_87["Unnamed: 0"]


machine_ID_87["time_diff"] = np.nan

machine_ID_87.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_87.index:
    
    machine_ID_87.at[(idx+1), 'time_diff'] = machine_ID_87.at[(idx), 'time_diff'] + 3.0 

machine_ID_87 = machine_ID_87.drop([2913])    


machine_ID_87.to_csv('machine_ID_87.csv') # save file

# %%
#machine88




machine_ID_88 = df.loc[df['machineID'] == 88]
machine_ID_88.to_csv('machine_ID_88.csv')


machine_ID_88 = pd.read_csv("machine_ID_88.csv")

del machine_ID_88["Unnamed: 0"]


machine_ID_88["time_diff"] = np.nan

machine_ID_88.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_88.index:
    
    machine_ID_88.at[(idx+1), 'time_diff'] = machine_ID_88.at[(idx), 'time_diff'] + 3.0 

machine_ID_88 = machine_ID_88.drop([2913])    


machine_ID_88.to_csv('machine_ID_88.csv') # save file

# %%
#machine89




machine_ID_89 = df.loc[df['machineID'] == 89]
machine_ID_89.to_csv('machine_ID_89.csv')


machine_ID_89 = pd.read_csv("machine_ID_89.csv")

del machine_ID_89["Unnamed: 0"]


machine_ID_89["time_diff"] = np.nan

machine_ID_89.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_89.index:
    
    machine_ID_89.at[(idx+1), 'time_diff'] = machine_ID_89.at[(idx), 'time_diff'] + 3.0 

machine_ID_89 = machine_ID_89.drop([2913])    


machine_ID_89.to_csv('machine_ID_89.csv') # save file

# %%
#machine90




machine_ID_90 = df.loc[df['machineID'] == 90]
machine_ID_90.to_csv('machine_ID_90.csv')


machine_ID_90 = pd.read_csv("machine_ID_90.csv")

del machine_ID_90["Unnamed: 0"]


machine_ID_90["time_diff"] = np.nan

machine_ID_90.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_90.index:
    
    machine_ID_90.at[(idx+1), 'time_diff'] = machine_ID_90.at[(idx), 'time_diff'] + 3.0 

machine_ID_90 = machine_ID_90.drop([2913])    


machine_ID_90.to_csv('machine_ID_90.csv') # save file

# %%
#machine91




machine_ID_91 = df.loc[df['machineID'] == 91]
machine_ID_91.to_csv('machine_ID_91.csv')


machine_ID_91 = pd.read_csv("machine_ID_91.csv")

del machine_ID_91["Unnamed: 0"]


machine_ID_91["time_diff"] = np.nan

machine_ID_91.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_91.index:
    
    machine_ID_91.at[(idx+1), 'time_diff'] = machine_ID_91.at[(idx), 'time_diff'] + 3.0 

machine_ID_91 = machine_ID_91.drop([2913])    


machine_ID_91.to_csv('machine_ID_91.csv') # save file

# %%
#machine92





machine_ID_92 = df.loc[df['machineID'] == 92]
machine_ID_92.to_csv('machine_ID_92.csv')


machine_ID_92 = pd.read_csv("machine_ID_92.csv")

del machine_ID_92["Unnamed: 0"]


machine_ID_92["time_diff"] = np.nan

machine_ID_92.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_92.index:
    
    machine_ID_92.at[(idx+1), 'time_diff'] = machine_ID_92.at[(idx), 'time_diff'] + 3.0 

machine_ID_92 = machine_ID_92.drop([2913])    


machine_ID_92.to_csv('machine_ID_92.csv') # save file

# %%
#machine93




machine_ID_93 = df.loc[df['machineID'] == 93]
machine_ID_93.to_csv('machine_ID_93.csv')


machine_ID_93 = pd.read_csv("machine_ID_93.csv")

del machine_ID_93["Unnamed: 0"]


machine_ID_93["time_diff"] = np.nan

machine_ID_93.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_93.index:
    
    machine_ID_93.at[(idx+1), 'time_diff'] = machine_ID_93.at[(idx), 'time_diff'] + 3.0 

machine_ID_93 = machine_ID_93.drop([2913])    


machine_ID_93.to_csv('machine_ID_93.csv') # save file

# %%
#machine94




machine_ID_94 = df.loc[df['machineID'] == 94]
machine_ID_94.to_csv('machine_ID_94.csv')


machine_ID_94 = pd.read_csv("machine_ID_94.csv")

del machine_ID_94["Unnamed: 0"]


machine_ID_94["time_diff"] = np.nan

machine_ID_94.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_94.index:
    
    machine_ID_94.at[(idx+1), 'time_diff'] = machine_ID_94.at[(idx), 'time_diff'] + 3.0 

machine_ID_94 = machine_ID_94.drop([2913])    


machine_ID_94.to_csv('machine_ID_94.csv') # save file

# %%
#machine95




machine_ID_95 = df.loc[df['machineID'] == 95]
machine_ID_95.to_csv('machine_ID_95.csv')


machine_ID_95 = pd.read_csv("machine_ID_95.csv")

del machine_ID_95["Unnamed: 0"]


machine_ID_95["time_diff"] = np.nan

machine_ID_95.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_95.index:
    
    machine_ID_95.at[(idx+1), 'time_diff'] = machine_ID_95.at[(idx), 'time_diff'] + 3.0 

machine_ID_95 = machine_ID_95.drop([2913])    


machine_ID_95.to_csv('machine_ID_95.csv') # save file

# %%
#machine96




machine_ID_96 = df.loc[df['machineID'] == 96]
machine_ID_96.to_csv('machine_ID_96.csv')


machine_ID_96 = pd.read_csv("machine_ID_96.csv")

del machine_ID_96["Unnamed: 0"]


machine_ID_96["time_diff"] = np.nan

machine_ID_96.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_96.index:
    
    machine_ID_96.at[(idx+1), 'time_diff'] = machine_ID_96.at[(idx), 'time_diff'] + 3.0 

machine_ID_96 = machine_ID_96.drop([2913])    


machine_ID_96.to_csv('machine_ID_96.csv') # save file

# %%
#machine97




machine_ID_97 = df.loc[df['machineID'] == 97]
machine_ID_97.to_csv('machine_ID_97.csv')


machine_ID_97 = pd.read_csv("machine_ID_97.csv")

del machine_ID_97["Unnamed: 0"]


machine_ID_97["time_diff"] = np.nan

machine_ID_97.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_97.index:
    
    machine_ID_97.at[(idx+1), 'time_diff'] = machine_ID_97.at[(idx), 'time_diff'] + 3.0 

machine_ID_97 = machine_ID_97.drop([2913])    


machine_ID_97.to_csv('machine_ID_97.csv') # save file

# %%
#machine98




machine_ID_98 = df.loc[df['machineID'] == 98]
machine_ID_98.to_csv('machine_ID_98.csv')


machine_ID_98 = pd.read_csv("machine_ID_98.csv")

del machine_ID_98["Unnamed: 0"]


machine_ID_98["time_diff"] = np.nan

machine_ID_98.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_98.index:
    
    machine_ID_98.at[(idx+1), 'time_diff'] = machine_ID_98.at[(idx), 'time_diff'] + 3.0 

machine_ID_98 = machine_ID_98.drop([2913])    


machine_ID_98.to_csv('machine_ID_98.csv') # save file

# %%
#machine99




machine_ID_99 = df.loc[df['machineID'] == 99]
machine_ID_99.to_csv('machine_ID_99.csv')


machine_ID_99 = pd.read_csv("machine_ID_99.csv")

del machine_ID_99["Unnamed: 0"]


machine_ID_99["time_diff"] = np.nan

machine_ID_99.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_99.index:
    
    machine_ID_99.at[(idx+1), 'time_diff'] = machine_ID_99.at[(idx), 'time_diff'] + 3.0 

machine_ID_99 = machine_ID_99.drop([2913])    


machine_ID_99.to_csv('machine_ID_99.csv') # save file

# %%
#machine100




machine_ID_100 = df.loc[df['machineID'] == 100]
machine_ID_100.to_csv('machine_ID_100.csv')


machine_ID_100 = pd.read_csv("machine_ID_100.csv")

del machine_ID_100["Unnamed: 0"]


machine_ID_100["time_diff"] = np.nan

machine_ID_100.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_100.index:
    
    machine_ID_100.at[(idx+1), 'time_diff'] = machine_ID_100.at[(idx), 'time_diff'] + 3.0 

machine_ID_100 = machine_ID_100.drop([2913])    


machine_ID_100.to_csv('machine_ID_100.csv') # save file
