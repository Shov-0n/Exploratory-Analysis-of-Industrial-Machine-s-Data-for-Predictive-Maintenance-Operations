# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("features.csv")

# %%
#machine11

machine_ID_11 = df.loc[df['machineID'] == 11]
machine_ID_11.to_csv('machine_ID_11.csv')


machine_ID_11 = pd.read_csv("machine_ID_11.csv")

del machine_ID_11["Unnamed: 0"]


machine_ID_11["time_diff"] = np.nan

machine_ID_11.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_11.index:
    
    machine_ID_11.at[(idx+1), 'time_diff'] = machine_ID_11.at[(idx), 'time_diff'] + 3.0 

machine_ID_11 = machine_ID_11.drop([2913])    


machine_ID_11.to_csv('machine_ID_11.csv') # save file

# %%
#machine12




machine_ID_12 = df.loc[df['machineID'] == 12]
machine_ID_12.to_csv('machine_ID_12.csv')


machine_ID_12 = pd.read_csv("machine_ID_12.csv")

del machine_ID_12["Unnamed: 0"]


machine_ID_12["time_diff"] = np.nan

machine_ID_12.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_12.index:
    
    machine_ID_12.at[(idx+1), 'time_diff'] = machine_ID_12.at[(idx), 'time_diff'] + 3.0 

machine_ID_12 = machine_ID_12.drop([2913])    


machine_ID_12.to_csv('machine_ID_12.csv') # save file

# %%
#machine13





machine_ID_13 = df.loc[df['machineID'] == 13]
machine_ID_13.to_csv('machine_ID_13.csv')


machine_ID_13 = pd.read_csv("machine_ID_13.csv")

del machine_ID_13["Unnamed: 0"]


machine_ID_13["time_diff"] = np.nan

machine_ID_13.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_13.index:
    
    machine_ID_13.at[(idx+1), 'time_diff'] = machine_ID_13.at[(idx), 'time_diff'] + 3.0 

machine_ID_13 = machine_ID_13.drop([2913])    


machine_ID_13.to_csv('machine_ID_13.csv') # save file

# %%
#machine14




machine_ID_14 = df.loc[df['machineID'] == 14]
machine_ID_14.to_csv('machine_ID_14.csv')


machine_ID_14 = pd.read_csv("machine_ID_14.csv")

del machine_ID_14["Unnamed: 0"]


machine_ID_14["time_diff"] = np.nan

machine_ID_14.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_14.index:
    
    machine_ID_14.at[(idx+1), 'time_diff'] = machine_ID_14.at[(idx), 'time_diff'] + 3.0 

machine_ID_14 = machine_ID_14.drop([2913])    


machine_ID_14.to_csv('machine_ID_14.csv') # save file

# %%
#machine15





machine_ID_15 = df.loc[df['machineID'] == 15]
machine_ID_15.to_csv('machine_ID_15.csv')


machine_ID_15 = pd.read_csv("machine_ID_15.csv")

del machine_ID_15["Unnamed: 0"]


machine_ID_15["time_diff"] = np.nan

machine_ID_15.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_15.index:
    
    machine_ID_15.at[(idx+1), 'time_diff'] = machine_ID_15.at[(idx), 'time_diff'] + 3.0 

machine_ID_15 = machine_ID_15.drop([2913])    


machine_ID_15.to_csv('machine_ID_15.csv') # save file

# %%
#machine16



machine_ID_16 = df.loc[df['machineID'] == 16]
machine_ID_16.to_csv('machine_ID_16.csv')


machine_ID_16 = pd.read_csv("machine_ID_16.csv")

del machine_ID_16["Unnamed: 0"]


machine_ID_16["time_diff"] = np.nan

machine_ID_16.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_16.index:
    
    machine_ID_16.at[(idx+1), 'time_diff'] = machine_ID_16.at[(idx), 'time_diff'] + 3.0 

machine_ID_16 = machine_ID_16.drop([2913])    


machine_ID_16.to_csv('machine_ID_16.csv') # save file

# %%
#machine17




machine_ID_17 = df.loc[df['machineID'] == 17]
machine_ID_17.to_csv('machine_ID_17.csv')


machine_ID_17 = pd.read_csv("machine_ID_17.csv")

del machine_ID_17["Unnamed: 0"]


machine_ID_17["time_diff"] = np.nan

machine_ID_17.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_17.index:
    
    machine_ID_17.at[(idx+1), 'time_diff'] = machine_ID_17.at[(idx), 'time_diff'] + 3.0 

machine_ID_17 = machine_ID_17.drop([2913])    


machine_ID_17.to_csv('machine_ID_17.csv') # save file

# %%
#machine18




machine_ID_18 = df.loc[df['machineID'] == 18]
machine_ID_18.to_csv('machine_ID_18.csv')


machine_ID_18 = pd.read_csv("machine_ID_18.csv")

del machine_ID_18["Unnamed: 0"]


machine_ID_18["time_diff"] = np.nan

machine_ID_18.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_18.index:
    
    machine_ID_18.at[(idx+1), 'time_diff'] = machine_ID_18.at[(idx), 'time_diff'] + 3.0 

machine_ID_18 = machine_ID_18.drop([2913])    


machine_ID_18.to_csv('machine_ID_18.csv') # save file

# %%
#machine19




machine_ID_19 = df.loc[df['machineID'] == 19]
machine_ID_19.to_csv('machine_ID_19.csv')


machine_ID_19 = pd.read_csv("machine_ID_19.csv")

del machine_ID_19["Unnamed: 0"]


machine_ID_19["time_diff"] = np.nan

machine_ID_19.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_19.index:
    
    machine_ID_19.at[(idx+1), 'time_diff'] = machine_ID_19.at[(idx), 'time_diff'] + 3.0 

machine_ID_19 = machine_ID_19.drop([2913])    


machine_ID_19.to_csv('machine_ID_19.csv') # save file

# %%
#machine20



machine_ID_20 = df.loc[df['machineID'] == 20]
machine_ID_20.to_csv('machine_ID_20.csv')


machine_ID_20 = pd.read_csv("machine_ID_20.csv")

del machine_ID_20["Unnamed: 0"]


machine_ID_20["time_diff"] = np.nan

machine_ID_20.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_20.index:
    
    machine_ID_20.at[(idx+1), 'time_diff'] = machine_ID_20.at[(idx), 'time_diff'] + 3.0 

machine_ID_20 = machine_ID_20.drop([2913])    


machine_ID_20.to_csv('machine_ID_20.csv') # save file

# %%
#machine21




machine_ID_21 = df.loc[df['machineID'] == 21]
machine_ID_21.to_csv('machine_ID_21.csv')


machine_ID_21 = pd.read_csv("machine_ID_21.csv")

del machine_ID_21["Unnamed: 0"]


machine_ID_21["time_diff"] = np.nan

machine_ID_21.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_21.index:
    
    machine_ID_21.at[(idx+1), 'time_diff'] = machine_ID_21.at[(idx), 'time_diff'] + 3.0 

machine_ID_21 = machine_ID_21.drop([2913])    


machine_ID_21.to_csv('machine_ID_21.csv') # save file

# %%
#machine22




machine_ID_22 = df.loc[df['machineID'] == 22]
machine_ID_22.to_csv('machine_ID_22.csv')


machine_ID_22 = pd.read_csv("machine_ID_22.csv")

del machine_ID_22["Unnamed: 0"]


machine_ID_22["time_diff"] = np.nan

machine_ID_22.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_22.index:
    
    machine_ID_22.at[(idx+1), 'time_diff'] = machine_ID_22.at[(idx), 'time_diff'] + 3.0 

machine_ID_22 = machine_ID_22.drop([2913])    


machine_ID_22.to_csv('machine_ID_22.csv') # save file

# %%
#machine23




machine_ID_23 = df.loc[df['machineID'] == 23]
machine_ID_23.to_csv('machine_ID_23.csv')


machine_ID_23 = pd.read_csv("machine_ID_23.csv")

del machine_ID_23["Unnamed: 0"]


machine_ID_23["time_diff"] = np.nan

machine_ID_23.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_23.index:
    
    machine_ID_23.at[(idx+1), 'time_diff'] = machine_ID_23.at[(idx), 'time_diff'] + 3.0 

machine_ID_23 = machine_ID_23.drop([2913])    


machine_ID_23.to_csv('machine_ID_23.csv') # save file

# %%
#machine24




machine_ID_24 = df.loc[df['machineID'] == 24]
machine_ID_24.to_csv('machine_ID_24.csv')


machine_ID_24 = pd.read_csv("machine_ID_24.csv")

del machine_ID_24["Unnamed: 0"]


machine_ID_24["time_diff"] = np.nan

machine_ID_24.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_24.index:
    
    machine_ID_24.at[(idx+1), 'time_diff'] = machine_ID_24.at[(idx), 'time_diff'] + 3.0 

machine_ID_24 = machine_ID_24.drop([2913])    


machine_ID_24.to_csv('machine_ID_24.csv') # save file

# %%
#machine25




machine_ID_25 = df.loc[df['machineID'] == 25]
machine_ID_25.to_csv('machine_ID_25.csv')


machine_ID_25 = pd.read_csv("machine_ID_25.csv")

del machine_ID_25["Unnamed: 0"]


machine_ID_25["time_diff"] = np.nan

machine_ID_25.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_25.index:
    
    machine_ID_25.at[(idx+1), 'time_diff'] = machine_ID_25.at[(idx), 'time_diff'] + 3.0 

machine_ID_25 = machine_ID_25.drop([2913])    


machine_ID_25.to_csv('machine_ID_25.csv') # save file

# %%
#machine26




machine_ID_26 = df.loc[df['machineID'] == 26]
machine_ID_26.to_csv('machine_ID_26.csv')


machine_ID_26 = pd.read_csv("machine_ID_26.csv")

del machine_ID_26["Unnamed: 0"]


machine_ID_26["time_diff"] = np.nan

machine_ID_26.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_26.index:
    
    machine_ID_26.at[(idx+1), 'time_diff'] = machine_ID_26.at[(idx), 'time_diff'] + 3.0 

machine_ID_26 = machine_ID_26.drop([2913])    


machine_ID_26.to_csv('machine_ID_26.csv') # save file

# %%
#machine27




machine_ID_27 = df.loc[df['machineID'] == 27]
machine_ID_27.to_csv('machine_ID_27.csv')


machine_ID_27 = pd.read_csv("machine_ID_27.csv")

del machine_ID_27["Unnamed: 0"]


machine_ID_27["time_diff"] = np.nan

machine_ID_27.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_27.index:
    
    machine_ID_27.at[(idx+1), 'time_diff'] = machine_ID_27.at[(idx), 'time_diff'] + 3.0 

machine_ID_27 = machine_ID_27.drop([2913])    


machine_ID_27.to_csv('machine_ID_27.csv') # save file

# %%
#machine28





machine_ID_28 = df.loc[df['machineID'] == 28]
machine_ID_28.to_csv('machine_ID_28.csv')


machine_ID_28 = pd.read_csv("machine_ID_28.csv")

del machine_ID_28["Unnamed: 0"]


machine_ID_28["time_diff"] = np.nan

machine_ID_28.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_28.index:
    
    machine_ID_28.at[(idx+1), 'time_diff'] = machine_ID_28.at[(idx), 'time_diff'] + 3.0 

machine_ID_28 = machine_ID_28.drop([2913])    


machine_ID_28.to_csv('machine_ID_28.csv') # save file

# %%
#machine29




machine_ID_29 = df.loc[df['machineID'] == 29]
machine_ID_29.to_csv('machine_ID_29.csv')


machine_ID_29 = pd.read_csv("machine_ID_29.csv")

del machine_ID_29["Unnamed: 0"]


machine_ID_29["time_diff"] = np.nan

machine_ID_29.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_29.index:
    
    machine_ID_29.at[(idx+1), 'time_diff'] = machine_ID_29.at[(idx), 'time_diff'] + 3.0 

machine_ID_29 = machine_ID_29.drop([2913])    


machine_ID_29.to_csv('machine_ID_29.csv') # save file

# %%
#machine30





machine_ID_30 = df.loc[df['machineID'] == 30]
machine_ID_30.to_csv('machine_ID_30.csv')


machine_ID_30 = pd.read_csv("machine_ID_30.csv")

del machine_ID_30["Unnamed: 0"]


machine_ID_30["time_diff"] = np.nan

machine_ID_30.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_30.index:
    
    machine_ID_30.at[(idx+1), 'time_diff'] = machine_ID_30.at[(idx), 'time_diff'] + 3.0 

machine_ID_30 = machine_ID_30.drop([2913])    


machine_ID_30.to_csv('machine_ID_30.csv') # save file

# %%
#machine31




machine_ID_31 = df.loc[df['machineID'] == 31]
machine_ID_31.to_csv('machine_ID_31.csv')


machine_ID_31 = pd.read_csv("machine_ID_31.csv")

del machine_ID_31["Unnamed: 0"]


machine_ID_31["time_diff"] = np.nan

machine_ID_31.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_31.index:
    
    machine_ID_31.at[(idx+1), 'time_diff'] = machine_ID_31.at[(idx), 'time_diff'] + 3.0 

machine_ID_31 = machine_ID_31.drop([2913])    


machine_ID_31.to_csv('machine_ID_31.csv') # save file

# %%
#machine32




machine_ID_32 = df.loc[df['machineID'] == 32]
machine_ID_32.to_csv('machine_ID_32.csv')


machine_ID_32 = pd.read_csv("machine_ID_32.csv")

del machine_ID_32["Unnamed: 0"]


machine_ID_32["time_diff"] = np.nan

machine_ID_32.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_32.index:
    
    machine_ID_32.at[(idx+1), 'time_diff'] = machine_ID_32.at[(idx), 'time_diff'] + 3.0 

machine_ID_32 = machine_ID_32.drop([2913])    


machine_ID_32.to_csv('machine_ID_32.csv') # save file

# %%
#machine33




machine_ID_33 = df.loc[df['machineID'] == 33]
machine_ID_33.to_csv('machine_ID_33.csv')


machine_ID_33 = pd.read_csv("machine_ID_33.csv")

del machine_ID_33["Unnamed: 0"]


machine_ID_33["time_diff"] = np.nan

machine_ID_33.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_33.index:
    
    machine_ID_33.at[(idx+1), 'time_diff'] = machine_ID_33.at[(idx), 'time_diff'] + 3.0 

machine_ID_33 = machine_ID_33.drop([2913])    


machine_ID_33.to_csv('machine_ID_33.csv') # save file

# %%
#machine34




machine_ID_34 = df.loc[df['machineID'] == 34]
machine_ID_34.to_csv('machine_ID_34.csv')


machine_ID_34 = pd.read_csv("machine_ID_34.csv")

del machine_ID_34["Unnamed: 0"]


machine_ID_34["time_diff"] = np.nan

machine_ID_34.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_34.index:
    
    machine_ID_34.at[(idx+1), 'time_diff'] = machine_ID_34.at[(idx), 'time_diff'] + 3.0 

machine_ID_34 = machine_ID_34.drop([2913])    


machine_ID_34.to_csv('machine_ID_34.csv') # save file

# %%
#machine35




machine_ID_35 = df.loc[df['machineID'] == 35]
machine_ID_35.to_csv('machine_ID_35.csv')


machine_ID_35 = pd.read_csv("machine_ID_35.csv")

del machine_ID_35["Unnamed: 0"]


machine_ID_35["time_diff"] = np.nan

machine_ID_35.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_35.index:
    
    machine_ID_35.at[(idx+1), 'time_diff'] = machine_ID_35.at[(idx), 'time_diff'] + 3.0 

machine_ID_35 = machine_ID_35.drop([2913])    


machine_ID_35.to_csv('machine_ID_35.csv') # save file

# %%
#machine36




machine_ID_36 = df.loc[df['machineID'] == 36]
machine_ID_36.to_csv('machine_ID_36.csv')


machine_ID_36 = pd.read_csv("machine_ID_36.csv")

del machine_ID_36["Unnamed: 0"]


machine_ID_36["time_diff"] = np.nan

machine_ID_36.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_36.index:
    
    machine_ID_36.at[(idx+1), 'time_diff'] = machine_ID_36.at[(idx), 'time_diff'] + 3.0 

machine_ID_36 = machine_ID_36.drop([2913])    


machine_ID_36.to_csv('machine_ID_36.csv') # save file

# %%
#machine37




machine_ID_37 = df.loc[df['machineID'] == 37]
machine_ID_37.to_csv('machine_ID_37.csv')


machine_ID_37 = pd.read_csv("machine_ID_37.csv")

del machine_ID_37["Unnamed: 0"]


machine_ID_37["time_diff"] = np.nan

machine_ID_37.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_37.index:
    
    machine_ID_37.at[(idx+1), 'time_diff'] = machine_ID_37.at[(idx), 'time_diff'] + 3.0 

machine_ID_37 = machine_ID_37.drop([2913])    


machine_ID_37.to_csv('machine_ID_37.csv') # save file

# %%
#machine38





machine_ID_38 = df.loc[df['machineID'] == 38]
machine_ID_38.to_csv('machine_ID_38.csv')


machine_ID_38 = pd.read_csv("machine_ID_38.csv")

del machine_ID_38["Unnamed: 0"]


machine_ID_38["time_diff"] = np.nan

machine_ID_38.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_38.index:
    
    machine_ID_38.at[(idx+1), 'time_diff'] = machine_ID_38.at[(idx), 'time_diff'] + 3.0 

machine_ID_38 = machine_ID_38.drop([2913])    


machine_ID_38.to_csv('machine_ID_38.csv') # save file

# %%
#machine39




machine_ID_39 = df.loc[df['machineID'] == 39]
machine_ID_39.to_csv('machine_ID_39.csv')


machine_ID_39 = pd.read_csv("machine_ID_39.csv")

del machine_ID_39["Unnamed: 0"]


machine_ID_39["time_diff"] = np.nan

machine_ID_39.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_39.index:
    
    machine_ID_39.at[(idx+1), 'time_diff'] = machine_ID_39.at[(idx), 'time_diff'] + 3.0 

machine_ID_39 = machine_ID_39.drop([2913])    


machine_ID_39.to_csv('machine_ID_39.csv') # save file

# %%
#machine40





machine_ID_40 = df.loc[df['machineID'] == 40]
machine_ID_40.to_csv('machine_ID_40.csv')


machine_ID_40 = pd.read_csv("machine_ID_40.csv")

del machine_ID_40["Unnamed: 0"]


machine_ID_40["time_diff"] = np.nan

machine_ID_40.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_40.index:
    
    machine_ID_40.at[(idx+1), 'time_diff'] = machine_ID_40.at[(idx), 'time_diff'] + 3.0 

machine_ID_40 = machine_ID_40.drop([2913])    


machine_ID_40.to_csv('machine_ID_40.csv') # save file

# %%
#machine41





machine_ID_41 = df.loc[df['machineID'] == 41]
machine_ID_41.to_csv('machine_ID_41.csv')


machine_ID_41 = pd.read_csv("machine_ID_41.csv")

del machine_ID_41["Unnamed: 0"]


machine_ID_41["time_diff"] = np.nan

machine_ID_41.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_41.index:
    
    machine_ID_41.at[(idx+1), 'time_diff'] = machine_ID_41.at[(idx), 'time_diff'] + 3.0 

machine_ID_41 = machine_ID_41.drop([2913])    


machine_ID_41.to_csv('machine_ID_41.csv') # save file

# %%
#machine42




machine_ID_42 = df.loc[df['machineID'] == 42]
machine_ID_42.to_csv('machine_ID_42.csv')


machine_ID_42 = pd.read_csv("machine_ID_42.csv")

del machine_ID_42["Unnamed: 0"]


machine_ID_42["time_diff"] = np.nan

machine_ID_42.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_42.index:
    
    machine_ID_42.at[(idx+1), 'time_diff'] = machine_ID_42.at[(idx), 'time_diff'] + 3.0 

machine_ID_42 = machine_ID_42.drop([2913])    


machine_ID_42.to_csv('machine_ID_42.csv') # save file

# %%
#machine43




machine_ID_43 = df.loc[df['machineID'] == 43]
machine_ID_43.to_csv('machine_ID_43.csv')


machine_ID_43 = pd.read_csv("machine_ID_43.csv")

del machine_ID_43["Unnamed: 0"]


machine_ID_43["time_diff"] = np.nan

machine_ID_43.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_43.index:
    
    machine_ID_43.at[(idx+1), 'time_diff'] = machine_ID_43.at[(idx), 'time_diff'] + 3.0 

machine_ID_43 = machine_ID_43.drop([2913])    


machine_ID_43.to_csv('machine_ID_43.csv') # save file

# %%
#machine44





machine_ID_44 = df.loc[df['machineID'] == 44]
machine_ID_44.to_csv('machine_ID_44.csv')


machine_ID_44 = pd.read_csv("machine_ID_44.csv")

del machine_ID_44["Unnamed: 0"]


machine_ID_44["time_diff"] = np.nan

machine_ID_44.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_44.index:
    
    machine_ID_44.at[(idx+1), 'time_diff'] = machine_ID_44.at[(idx), 'time_diff'] + 3.0 

machine_ID_44 = machine_ID_44.drop([2913])    


machine_ID_44.to_csv('machine_ID_44.csv') # save file

# %%
#machine45





machine_ID_45 = df.loc[df['machineID'] == 45]
machine_ID_45.to_csv('machine_ID_45.csv')


machine_ID_45 = pd.read_csv("machine_ID_45.csv")

del machine_ID_45["Unnamed: 0"]


machine_ID_45["time_diff"] = np.nan

machine_ID_45.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_45.index:
    
    machine_ID_45.at[(idx+1), 'time_diff'] = machine_ID_45.at[(idx), 'time_diff'] + 3.0 

machine_ID_45 = machine_ID_45.drop([2913])    


machine_ID_45.to_csv('machine_ID_45.csv') # save file

# %%
#machine46




machine_ID_46 = df.loc[df['machineID'] == 46]
machine_ID_46.to_csv('machine_ID_46.csv')


machine_ID_46 = pd.read_csv("machine_ID_46.csv")

del machine_ID_46["Unnamed: 0"]


machine_ID_46["time_diff"] = np.nan

machine_ID_46.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_46.index:
    
    machine_ID_46.at[(idx+1), 'time_diff'] = machine_ID_46.at[(idx), 'time_diff'] + 3.0 

machine_ID_46 = machine_ID_46.drop([2913])    


machine_ID_46.to_csv('machine_ID_46.csv') # save file

# %%
#machine47




machine_ID_47 = df.loc[df['machineID'] == 47]
machine_ID_47.to_csv('machine_ID_47.csv')


machine_ID_47 = pd.read_csv("machine_ID_47.csv")

del machine_ID_47["Unnamed: 0"]


machine_ID_47["time_diff"] = np.nan

machine_ID_47.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_47.index:
    
    machine_ID_47.at[(idx+1), 'time_diff'] = machine_ID_47.at[(idx), 'time_diff'] + 3.0 

machine_ID_47 = machine_ID_47.drop([2913])    


machine_ID_47.to_csv('machine_ID_47.csv') # save file

# %%
#machine48




machine_ID_48 = df.loc[df['machineID'] == 48]
machine_ID_48.to_csv('machine_ID_48.csv')


machine_ID_48 = pd.read_csv("machine_ID_48.csv")

del machine_ID_48["Unnamed: 0"]


machine_ID_48["time_diff"] = np.nan

machine_ID_48.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_48.index:
    
    machine_ID_48.at[(idx+1), 'time_diff'] = machine_ID_48.at[(idx), 'time_diff'] + 3.0 

machine_ID_48 = machine_ID_48.drop([2913])    


machine_ID_48.to_csv('machine_ID_48.csv') # save file

# %%
#machine49





machine_ID_49 = df.loc[df['machineID'] == 49]
machine_ID_49.to_csv('machine_ID_49.csv')


machine_ID_49 = pd.read_csv("machine_ID_49.csv")

del machine_ID_49["Unnamed: 0"]


machine_ID_49["time_diff"] = np.nan

machine_ID_49.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_49.index:
    
    machine_ID_49.at[(idx+1), 'time_diff'] = machine_ID_49.at[(idx), 'time_diff'] + 3.0 

machine_ID_49 = machine_ID_49.drop([2913])    


machine_ID_49.to_csv('machine_ID_49.csv') # save file

# %%
#machine50





machine_ID_50 = df.loc[df['machineID'] == 50]
machine_ID_50.to_csv('machine_ID_50.csv')


machine_ID_50 = pd.read_csv("machine_ID_50.csv")

del machine_ID_50["Unnamed: 0"]


machine_ID_50["time_diff"] = np.nan

machine_ID_50.loc[0, 'time_diff'] = 3.0 


for idx in machine_ID_50.index:
    
    machine_ID_50.at[(idx+1), 'time_diff'] = machine_ID_50.at[(idx), 'time_diff'] + 3.0 

machine_ID_50 = machine_ID_50.drop([2913])    


machine_ID_50.to_csv('machine_ID_50.csv') # save file
